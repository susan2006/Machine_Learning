# %%
import pandas as pd
import numpy as np
import math

# Entropy calculation
def entropy(target_col):
    elements, counts = np.unique(target_col, return_counts=True)
    total = np.sum(counts)
    ent = -np.sum([(count/total) * math.log2(count/total) for count in counts if count > 0])
    return ent

# Attribute entropy
def attr_entropy(data, attr, target, threshold=None):
    if threshold is not None:  # numerical attribute
        left_split = data[data[attr] < threshold]
        right_split = data[data[attr] >= threshold]
        total = len(data)
        return (len(left_split)/total) * entropy(left_split[target]) + \
               (len(right_split)/total) * entropy(right_split[target])
    else:  # categorical attribute
        values, counts = np.unique(data[attr], return_counts=True)
        total = np.sum(counts)
        return np.sum([(counts[i]/total) * entropy(data[data[attr] == values[i]][target])
                       for i in range(len(values))])

# Info gain
def info_gain(data, attr, target, threshold=None):
    total_ent = entropy(data[target])
    attr_ent = attr_entropy(data, attr, target, threshold)
    return total_ent - attr_ent

# Split info
def split_info(data, attr, threshold=None):
    if threshold is not None:  # numerical
        left_split = data[data[attr] < threshold]
        right_split = data[data[attr] >= threshold]
        total = len(data)
        splits = [len(left_split), len(right_split)]
    else:  # categorical
        _, counts = np.unique(data[attr], return_counts=True)
        splits = counts
        total = np.sum(counts)
    return -np.sum([(c/total) * math.log2(c/total) for c in splits if c > 0])

# Gain ratio (with printing)
def gain_ratio(data, attr, target, verbose=False):
    if np.issubdtype(data[attr].dtype, np.number):  # numerical feature
        values = np.sort(data[attr].unique())
        if len(values) == 1:  # all values same
            return 0, None
        thresholds = [(values[i] + values[i+1])/2 for i in range(len(values)-1)]
        best_gain_ratio = -1
        best_threshold = None
        for t in thresholds:
            ig = info_gain(data, attr, target, threshold=t)
            si = split_info(data, attr, threshold=t)
            gr = ig/si if si != 0 else 0
            if verbose:
                print(f"[NUM] {attr} | Threshold={t:.3f} | InfoGain={ig:.4f} | SplitInfo={si:.4f} | GainRatio={gr:.4f}")
            if gr > best_gain_ratio:
                best_gain_ratio = gr
                best_threshold = t
        return best_gain_ratio, best_threshold
    else:  # categorical feature
        ig = info_gain(data, attr, target)
        si = split_info(data, attr)
        gr = ig/si if si != 0 else 0
        if verbose:
            print(f"{attr} | InfoGain={ig:.4f} | SplitInfo={si:.4f} | GainRatio={gr:.4f}")
        return gr, None

# Recursive C4.5 algorithm
def C45(data, orig_data, features, target, parent_class=None, depth=0):
    prefix = "   " * depth
    if len(np.unique(data[target])) == 1:
        return np.unique(data[target])[0]
    elif len(data) == 0:
        return np.unique(orig_data[target])[np.argmax(np.unique(orig_data[target], return_counts=True)[1])]
    elif len(features) == 0:
        return parent_class
    else:
        parent_class = np.unique(data[target])[np.argmax(np.unique(data[target], return_counts=True)[1])]
        
        print(f"\n{prefix}Entropy(Target) = {entropy(data[target]):.4f}")
        print(f"{prefix}Checking features...")

        # Find best feature
        gains = [gain_ratio(data, f, target, verbose=True) for f in features]
        best_feature_index = np.argmax([g[0] for g in gains])
        best_feature = features[best_feature_index]
        best_gain, best_threshold = gains[best_feature_index]

        print(f"{prefix}--> Best Feature = {best_feature}, Best GainRatio = {best_gain:.4f}, Threshold = {best_threshold}")

        if best_gain == 0:
            return parent_class

        tree = {best_feature: {}}

        if best_threshold is not None:  # numerical split
            left_split = data[data[best_feature] < best_threshold]
            right_split = data[data[best_feature] >= best_threshold]
            sub_feat = [f for f in features if f != best_feature]
            tree[best_feature][f"< {best_threshold}"] = C45(left_split, orig_data, sub_feat, target, parent_class, depth+1)
            tree[best_feature][f">= {best_threshold}"] = C45(right_split, orig_data, sub_feat, target, parent_class, depth+1)
        else:  # categorical split
            for value in np.unique(data[best_feature]):
                sub_data = data[data[best_feature] == value]
                sub_feat = [f for f in features if f != best_feature]
                tree[best_feature][value] = C45(sub_data, orig_data, sub_feat, target, parent_class, depth+1)

        return tree


# ==== Usage ====
df = pd.read_csv("diabetes.csv")
target_attr = 'Outcome'
features = [f for f in df.columns if f != target_attr]

decision_tree = C45(df, df, features, target_attr)

import pprint
print("\nFinal Decision Tree:")
pprint.pprint(decision_tree)
# Out:
# Entropy(Target) = 0.9521
# Checking features...
# [NUM] Pregnancies | Threshold=0.500 | InfoGain=0.0061 | SplitInfo=0.5016 | GainRatio=0.0122
# [NUM] Pregnancies | Threshold=1.500 | InfoGain=0.0024 | SplitInfo=0.8505 | GainRatio=0.0028
# [NUM] Pregnancies | Threshold=2.500 | InfoGain=0.0254 | SplitInfo=0.9721 | GainRatio=0.0261
# [NUM] Pregnancies | Threshold=3.500 | InfoGain=0.0275 | SplitInfo=0.9985 | GainRatio=0.0275
# [NUM] Pregnancies | Threshold=4.500 | InfoGain=0.0442 | SplitInfo=0.9824 | GainRatio=0.0450
# [NUM] Pregnancies | Threshold=5.500 | InfoGain=0.0654 | SplitInfo=0.9006 | GainRatio=0.0726
# [NUM] Pregnancies | Threshold=6.500 | InfoGain=0.0690 | SplitInfo=0.8362 | GainRatio=0.0825
# [NUM] Pregnancies | Threshold=7.500 | InfoGain=0.0516 | SplitInfo=0.6481 | GainRatio=0.0797
# [NUM] Pregnancies | Threshold=8.500 | InfoGain=0.0214 | SplitInfo=0.4863 | GainRatio=0.0440
# [NUM] Pregnancies | Threshold=9.500 | InfoGain=0.0089 | SplitInfo=0.3672 | GainRatio=0.0244
# [NUM] Pregnancies | Threshold=10.500 | InfoGain=0.0079 | SplitInfo=0.2432 | GainRatio=0.0326
# [NUM] Pregnancies | Threshold=12.000 | InfoGain=0.0040 | SplitInfo=0.1693 | GainRatio=0.0234
# [NUM] Pregnancies | Threshold=14.000 | InfoGain=0.0145 | SplitInfo=0.0811 | GainRatio=0.1783
# [NUM] Pregnancies | Threshold=16.000 | InfoGain=0.0072 | SplitInfo=0.0456 | GainRatio=0.1579
# [NUM] Glucose | Threshold=22.000 | InfoGain=0.0068 | SplitInfo=0.0811 | GainRatio=0.0836
# [NUM] Glucose | Threshold=50.500 | InfoGain=0.0102 | SplitInfo=0.1128 | GainRatio=0.0905
# [NUM] Glucose | Threshold=59.500 | InfoGain=0.0137 | SplitInfo=0.1420 | GainRatio=0.0962
# [NUM] Glucose | Threshold=66.500 | InfoGain=0.0171 | SplitInfo=0.1693 | GainRatio=0.1012
# [NUM] Glucose | Threshold=72.000 | InfoGain=0.0241 | SplitInfo=0.2197 | GainRatio=0.1099
# [NUM] Glucose | Threshold=73.500 | InfoGain=0.0312 | SplitInfo=0.2658 | GainRatio=0.1176
# [NUM] Glucose | Threshold=74.500 | InfoGain=0.0348 | SplitInfo=0.2875 | GainRatio=0.1212
# [NUM] Glucose | Threshold=75.500 | InfoGain=0.0385 | SplitInfo=0.3084 | GainRatio=0.1247
# [NUM] Glucose | Threshold=77.000 | InfoGain=0.0421 | SplitInfo=0.3286 | GainRatio=0.1281
# [NUM] Glucose | Threshold=78.500 | InfoGain=0.0264 | SplitInfo=0.3672 | GainRatio=0.0718
# [NUM] Glucose | Threshold=79.500 | InfoGain=0.0327 | SplitInfo=0.4036 | GainRatio=0.0810
# [NUM] Glucose | Threshold=80.500 | InfoGain=0.0359 | SplitInfo=0.4210 | GainRatio=0.0853
# [NUM] Glucose | Threshold=82.000 | InfoGain=0.0426 | SplitInfo=0.4545 | GainRatio=0.0937
# [NUM] Glucose | Threshold=83.500 | InfoGain=0.0494 | SplitInfo=0.4863 | GainRatio=0.1017
# [NUM] Glucose | Threshold=84.500 | InfoGain=0.0565 | SplitInfo=0.5165 | GainRatio=0.1093
# [NUM] Glucose | Threshold=86.000 | InfoGain=0.0711 | SplitInfo=0.5728 | GainRatio=0.1241
# [NUM] Glucose | Threshold=87.500 | InfoGain=0.0786 | SplitInfo=0.5990 | GainRatio=0.1312
# [NUM] Glucose | Threshold=88.500 | InfoGain=0.0738 | SplitInfo=0.6481 | GainRatio=0.1139
# [NUM] Glucose | Threshold=89.500 | InfoGain=0.0813 | SplitInfo=0.6710 | GainRatio=0.1211
# [NUM] Glucose | Threshold=91.000 | InfoGain=0.0715 | SplitInfo=0.6929 | GainRatio=0.1032
# [NUM] Glucose | Threshold=92.500 | InfoGain=0.0787 | SplitInfo=0.7138 | GainRatio=0.1103
# [NUM] Glucose | Threshold=94.000 | InfoGain=0.0862 | SplitInfo=0.7338 | GainRatio=0.1175
# [NUM] Glucose | Threshold=95.500 | InfoGain=0.0813 | SplitInfo=0.7622 | GainRatio=0.1067
# [NUM] Glucose | Threshold=96.500 | InfoGain=0.0887 | SplitInfo=0.7800 | GainRatio=0.1138
# [NUM] Glucose | Threshold=98.000 | InfoGain=0.0964 | SplitInfo=0.7970 | GainRatio=0.1209
# [NUM] Glucose | Threshold=99.500 | InfoGain=0.1124 | SplitInfo=0.8287 | GainRatio=0.1356
# [NUM] Glucose | Threshold=100.500 | InfoGain=0.1043 | SplitInfo=0.8706 | GainRatio=0.1198
# [NUM] Glucose | Threshold=101.500 | InfoGain=0.1124 | SplitInfo=0.8831 | GainRatio=0.1273
# [NUM] Glucose | Threshold=102.500 | InfoGain=0.0991 | SplitInfo=0.9061 | GainRatio=0.1094
# [NUM] Glucose | Threshold=103.500 | InfoGain=0.1012 | SplitInfo=0.9264 | GainRatio=0.1092
# [NUM] Glucose | Threshold=104.500 | InfoGain=0.0919 | SplitInfo=0.9311 | GainRatio=0.0987
# [NUM] Glucose | Threshold=105.500 | InfoGain=0.0985 | SplitInfo=0.9521 | GainRatio=0.1034
# [NUM] Glucose | Threshold=106.500 | InfoGain=0.1147 | SplitInfo=0.9661 | GainRatio=0.1188
# [NUM] Glucose | Threshold=107.500 | InfoGain=0.1050 | SplitInfo=0.9776 | GainRatio=0.1074
# [NUM] Glucose | Threshold=108.500 | InfoGain=0.1006 | SplitInfo=0.9824 | GainRatio=0.1024
# [NUM] Glucose | Threshold=109.500 | InfoGain=0.0890 | SplitInfo=0.9934 | GainRatio=0.0896
# [NUM] Glucose | Threshold=110.500 | InfoGain=0.1010 | SplitInfo=0.9969 | GainRatio=0.1013
# [NUM] Glucose | Threshold=111.500 | InfoGain=0.1057 | SplitInfo=0.9995 | GainRatio=0.1058
# [NUM] Glucose | Threshold=112.500 | InfoGain=0.1101 | SplitInfo=0.9998 | GainRatio=0.1101
# [NUM] Glucose | Threshold=113.500 | InfoGain=0.1065 | SplitInfo=1.0000 | GainRatio=0.1065
# [NUM] Glucose | Threshold=114.500 | InfoGain=0.1076 | SplitInfo=0.9991 | GainRatio=0.1077
# [NUM] Glucose | Threshold=115.500 | InfoGain=0.1044 | SplitInfo=0.9978 | GainRatio=0.1046
# [NUM] Glucose | Threshold=116.500 | InfoGain=0.1088 | SplitInfo=0.9969 | GainRatio=0.1092
# [NUM] Glucose | Threshold=117.500 | InfoGain=0.1058 | SplitInfo=0.9947 | GainRatio=0.1063
# [NUM] Glucose | Threshold=118.500 | InfoGain=0.1029 | SplitInfo=0.9920 | GainRatio=0.1037
# [NUM] Glucose | Threshold=119.500 | InfoGain=0.1001 | SplitInfo=0.9886 | GainRatio=0.1012
# [NUM] Glucose | Threshold=121.000 | InfoGain=0.1093 | SplitInfo=0.9846 | GainRatio=0.1110
# [NUM] Glucose | Threshold=122.500 | InfoGain=0.0994 | SplitInfo=0.9776 | GainRatio=0.1017
# [NUM] Glucose | Threshold=123.500 | InfoGain=0.1088 | SplitInfo=0.9721 | GainRatio=0.1120
# [NUM] Glucose | Threshold=124.500 | InfoGain=0.1017 | SplitInfo=0.9692 | GainRatio=0.1049
# [NUM] Glucose | Threshold=125.500 | InfoGain=0.0972 | SplitInfo=0.9558 | GainRatio=0.1017
# [NUM] Glucose | Threshold=127.000 | InfoGain=0.0999 | SplitInfo=0.9442 | GainRatio=0.1058
# [NUM] Glucose | Threshold=128.500 | InfoGain=0.0980 | SplitInfo=0.9356 | GainRatio=0.1047
# [NUM] Glucose | Threshold=129.500 | InfoGain=0.1012 | SplitInfo=0.9216 | GainRatio=0.1098
# [NUM] Glucose | Threshold=130.500 | InfoGain=0.0944 | SplitInfo=0.9166 | GainRatio=0.1030
# [NUM] Glucose | Threshold=131.500 | InfoGain=0.0816 | SplitInfo=0.9061 | GainRatio=0.0900
# [NUM] Glucose | Threshold=132.500 | InfoGain=0.0863 | SplitInfo=0.9006 | GainRatio=0.0958
# [NUM] Glucose | Threshold=133.500 | InfoGain=0.0848 | SplitInfo=0.8891 | GainRatio=0.0954
# [NUM] Glucose | Threshold=134.500 | InfoGain=0.0727 | SplitInfo=0.8769 | GainRatio=0.0828
# [NUM] Glucose | Threshold=135.500 | InfoGain=0.0669 | SplitInfo=0.8706 | GainRatio=0.0768
# [NUM] Glucose | Threshold=136.500 | InfoGain=0.0656 | SplitInfo=0.8574 | GainRatio=0.0765
# [NUM] Glucose | Threshold=137.500 | InfoGain=0.0548 | SplitInfo=0.8434 | GainRatio=0.0650
# [NUM] Glucose | Threshold=138.500 | InfoGain=0.0590 | SplitInfo=0.8362 | GainRatio=0.0705
# [NUM] Glucose | Threshold=140.000 | InfoGain=0.0623 | SplitInfo=0.8133 | GainRatio=0.0766
# [NUM] Glucose | Threshold=141.500 | InfoGain=0.0719 | SplitInfo=0.7970 | GainRatio=0.0902
# [NUM] Glucose | Threshold=142.500 | InfoGain=0.0772 | SplitInfo=0.7886 | GainRatio=0.0979
# [NUM] Glucose | Threshold=143.500 | InfoGain=0.0765 | SplitInfo=0.7712 | GainRatio=0.0992
# [NUM] Glucose | Threshold=144.500 | InfoGain=0.0883 | SplitInfo=0.7529 | GainRatio=0.1172
# [NUM] Glucose | Threshold=145.500 | InfoGain=0.0947 | SplitInfo=0.7435 | GainRatio=0.1274
# [NUM] Glucose | Threshold=146.500 | InfoGain=0.1097 | SplitInfo=0.7035 | GainRatio=0.1560
# [NUM] Glucose | Threshold=147.500 | InfoGain=0.1107 | SplitInfo=0.6821 | GainRatio=0.1623
# [NUM] Glucose | Threshold=149.000 | InfoGain=0.1121 | SplitInfo=0.6597 | GainRatio=0.1699
# [NUM] Glucose | Threshold=150.500 | InfoGain=0.1215 | SplitInfo=0.6481 | GainRatio=0.1875
# [NUM] Glucose | Threshold=151.500 | InfoGain=0.1438 | SplitInfo=0.6241 | GainRatio=0.2303
# [NUM] Glucose | Threshold=152.500 | InfoGain=0.1356 | SplitInfo=0.6117 | GainRatio=0.2217
# [NUM] Glucose | Threshold=153.500 | InfoGain=0.1487 | SplitInfo=0.5990 | GainRatio=0.2482
# [NUM] Glucose | Threshold=154.500 | InfoGain=0.1639 | SplitInfo=0.5861 | GainRatio=0.2797
# [NUM] Glucose | Threshold=155.500 | InfoGain=0.1553 | SplitInfo=0.5728 | GainRatio=0.2712
# [NUM] Glucose | Threshold=157.000 | InfoGain=0.1469 | SplitInfo=0.5592 | GainRatio=0.2626
# [NUM] Glucose | Threshold=158.500 | InfoGain=0.1303 | SplitInfo=0.5311 | GainRatio=0.2453
# [NUM] Glucose | Threshold=159.500 | InfoGain=0.1394 | SplitInfo=0.5016 | GainRatio=0.2778
# [NUM] Glucose | Threshold=161.000 | InfoGain=0.1310 | SplitInfo=0.4863 | GainRatio=0.2694
# [NUM] Glucose | Threshold=162.500 | InfoGain=0.1228 | SplitInfo=0.4706 | GainRatio=0.2609
# [NUM] Glucose | Threshold=164.500 | InfoGain=0.1066 | SplitInfo=0.4380 | GainRatio=0.2434
# [NUM] Glucose | Threshold=167.000 | InfoGain=0.0987 | SplitInfo=0.4210 | GainRatio=0.2345
# [NUM] Glucose | Threshold=169.000 | InfoGain=0.0909 | SplitInfo=0.4036 | GainRatio=0.2253
# [NUM] Glucose | Threshold=170.500 | InfoGain=0.0832 | SplitInfo=0.3857 | GainRatio=0.2158
# [NUM] Glucose | Threshold=172.000 | InfoGain=0.0682 | SplitInfo=0.3482 | GainRatio=0.1959
# [NUM] Glucose | Threshold=174.500 | InfoGain=0.0609 | SplitInfo=0.3286 | GainRatio=0.1853
# [NUM] Glucose | Threshold=177.500 | InfoGain=0.0537 | SplitInfo=0.3084 | GainRatio=0.1742
# [NUM] Glucose | Threshold=179.500 | InfoGain=0.0467 | SplitInfo=0.2875 | GainRatio=0.1623
# [NUM] Glucose | Threshold=180.500 | InfoGain=0.0594 | SplitInfo=0.2432 | GainRatio=0.2444
# [NUM] Glucose | Threshold=182.000 | InfoGain=0.0518 | SplitInfo=0.2197 | GainRatio=0.2357
# [NUM] Glucose | Threshold=185.000 | InfoGain=0.0442 | SplitInfo=0.1951 | GainRatio=0.2264
# [NUM] Glucose | Threshold=187.500 | InfoGain=0.0367 | SplitInfo=0.1693 | GainRatio=0.2165
# [NUM] Glucose | Threshold=188.500 | InfoGain=0.0292 | SplitInfo=0.1420 | GainRatio=0.2056
# [NUM] Glucose | Threshold=191.500 | InfoGain=0.0218 | SplitInfo=0.1128 | GainRatio=0.1932
# [NUM] Glucose | Threshold=195.000 | InfoGain=0.0145 | SplitInfo=0.0811 | GainRatio=0.1783
# [NUM] Glucose | Threshold=196.500 | InfoGain=0.0072 | SplitInfo=0.0456 | GainRatio=0.1579
# [NUM] BloodPressure | Threshold=15.000 | InfoGain=0.0000 | SplitInfo=0.2432 | GainRatio=0.0000
# [NUM] BloodPressure | Threshold=35.000 | InfoGain=0.0001 | SplitInfo=0.2875 | GainRatio=0.0004
# [NUM] BloodPressure | Threshold=42.000 | InfoGain=0.0012 | SplitInfo=0.3084 | GainRatio=0.0039
# [NUM] BloodPressure | Threshold=46.000 | InfoGain=0.0004 | SplitInfo=0.3286 | GainRatio=0.0012
# [NUM] BloodPressure | Threshold=49.000 | InfoGain=0.0004 | SplitInfo=0.3857 | GainRatio=0.0010
# [NUM] BloodPressure | Threshold=51.000 | InfoGain=0.0010 | SplitInfo=0.4545 | GainRatio=0.0023
# [NUM] BloodPressure | Threshold=53.000 | InfoGain=0.0028 | SplitInfo=0.4863 | GainRatio=0.0058
# [NUM] BloodPressure | Threshold=54.500 | InfoGain=0.0011 | SplitInfo=0.5016 | GainRatio=0.0022
# [NUM] BloodPressure | Threshold=55.500 | InfoGain=0.0028 | SplitInfo=0.5311 | GainRatio=0.0053
# [NUM] BloodPressure | Threshold=57.000 | InfoGain=0.0039 | SplitInfo=0.5861 | GainRatio=0.0066
# [NUM] BloodPressure | Threshold=59.000 | InfoGain=0.0125 | SplitInfo=0.6597 | GainRatio=0.0190
# [NUM] BloodPressure | Threshold=61.000 | InfoGain=0.0219 | SplitInfo=0.7435 | GainRatio=0.0294
# [NUM] BloodPressure | Threshold=63.000 | InfoGain=0.0231 | SplitInfo=0.8052 | GainRatio=0.0287
# [NUM] BloodPressure | Threshold=64.500 | InfoGain=0.0289 | SplitInfo=0.8891 | GainRatio=0.0325
# [NUM] BloodPressure | Threshold=65.500 | InfoGain=0.0360 | SplitInfo=0.9061 | GainRatio=0.0397
# [NUM] BloodPressure | Threshold=67.000 | InfoGain=0.0294 | SplitInfo=0.9692 | GainRatio=0.0303
# [NUM] BloodPressure | Threshold=69.000 | InfoGain=0.0224 | SplitInfo=0.9886 | GainRatio=0.0227
# [NUM] BloodPressure | Threshold=71.000 | InfoGain=0.0130 | SplitInfo=0.9998 | GainRatio=0.0130
# [NUM] BloodPressure | Threshold=73.000 | InfoGain=0.0022 | SplitInfo=0.9886 | GainRatio=0.0022
# [NUM] BloodPressure | Threshold=74.500 | InfoGain=0.0050 | SplitInfo=0.9482 | GainRatio=0.0052
# [NUM] BloodPressure | Threshold=75.500 | InfoGain=0.0084 | SplitInfo=0.9356 | GainRatio=0.0090
# [NUM] BloodPressure | Threshold=77.000 | InfoGain=0.0020 | SplitInfo=0.8891 | GainRatio=0.0022
# [NUM] BloodPressure | Threshold=79.000 | InfoGain=0.0086 | SplitInfo=0.8287 | GainRatio=0.0104
# [NUM] BloodPressure | Threshold=81.000 | InfoGain=0.0186 | SplitInfo=0.7435 | GainRatio=0.0250
# [NUM] BloodPressure | Threshold=83.000 | InfoGain=0.0254 | SplitInfo=0.6710 | GainRatio=0.0379
# [NUM] BloodPressure | Threshold=84.500 | InfoGain=0.0201 | SplitInfo=0.6117 | GainRatio=0.0329
# [NUM] BloodPressure | Threshold=85.500 | InfoGain=0.0194 | SplitInfo=0.5861 | GainRatio=0.0332
# [NUM] BloodPressure | Threshold=87.000 | InfoGain=0.0188 | SplitInfo=0.5592 | GainRatio=0.0337
# [NUM] BloodPressure | Threshold=89.000 | InfoGain=0.0106 | SplitInfo=0.4706 | GainRatio=0.0224
# [NUM] BloodPressure | Threshold=91.000 | InfoGain=0.0037 | SplitInfo=0.3672 | GainRatio=0.0101
# [NUM] BloodPressure | Threshold=93.000 | InfoGain=0.0179 | SplitInfo=0.2432 | GainRatio=0.0736
# [NUM] BloodPressure | Threshold=95.000 | InfoGain=0.0127 | SplitInfo=0.2197 | GainRatio=0.0578
# [NUM] BloodPressure | Threshold=97.000 | InfoGain=0.0143 | SplitInfo=0.1693 | GainRatio=0.0844
# [NUM] BloodPressure | Threshold=103.000 | InfoGain=0.0088 | SplitInfo=0.1420 | GainRatio=0.0617
# [NUM] BloodPressure | Threshold=109.000 | InfoGain=0.0039 | SplitInfo=0.1128 | GainRatio=0.0349
# [NUM] BloodPressure | Threshold=116.000 | InfoGain=0.0034 | SplitInfo=0.0456 | GainRatio=0.0742
# [NUM] SkinThickness | Threshold=5.000 | InfoGain=0.0012 | SplitInfo=0.9114 | GainRatio=0.0013
# [NUM] SkinThickness | Threshold=10.500 | InfoGain=0.0007 | SplitInfo=0.9166 | GainRatio=0.0008
# [NUM] SkinThickness | Threshold=11.500 | InfoGain=0.0002 | SplitInfo=0.9264 | GainRatio=0.0002
# [NUM] SkinThickness | Threshold=12.500 | InfoGain=0.0000 | SplitInfo=0.9311 | GainRatio=0.0000
# [NUM] SkinThickness | Threshold=13.500 | InfoGain=0.0000 | SplitInfo=0.9482 | GainRatio=0.0000
# [NUM] SkinThickness | Threshold=14.500 | InfoGain=0.0001 | SplitInfo=0.9521 | GainRatio=0.0001
# [NUM] SkinThickness | Threshold=16.000 | InfoGain=0.0006 | SplitInfo=0.9692 | GainRatio=0.0006
# [NUM] SkinThickness | Threshold=17.500 | InfoGain=0.0010 | SplitInfo=0.9721 | GainRatio=0.0010
# [NUM] SkinThickness | Threshold=18.500 | InfoGain=0.0028 | SplitInfo=0.9867 | GainRatio=0.0029
# [NUM] SkinThickness | Threshold=19.500 | InfoGain=0.0038 | SplitInfo=0.9934 | GainRatio=0.0038
# [NUM] SkinThickness | Threshold=20.500 | InfoGain=0.0069 | SplitInfo=0.9991 | GainRatio=0.0069
# [NUM] SkinThickness | Threshold=21.500 | InfoGain=0.0093 | SplitInfo=0.9998 | GainRatio=0.0093
# [NUM] SkinThickness | Threshold=22.500 | InfoGain=0.0106 | SplitInfo=1.0000 | GainRatio=0.0106
# [NUM] SkinThickness | Threshold=23.500 | InfoGain=0.0129 | SplitInfo=0.9969 | GainRatio=0.0129
# [NUM] SkinThickness | Threshold=24.500 | InfoGain=0.0096 | SplitInfo=0.9934 | GainRatio=0.0097
# [NUM] SkinThickness | Threshold=25.500 | InfoGain=0.0130 | SplitInfo=0.9846 | GainRatio=0.0132
# [NUM] SkinThickness | Threshold=26.500 | InfoGain=0.0142 | SplitInfo=0.9692 | GainRatio=0.0147
# [NUM] SkinThickness | Threshold=27.500 | InfoGain=0.0217 | SplitInfo=0.9558 | GainRatio=0.0227
# [NUM] SkinThickness | Threshold=28.500 | InfoGain=0.0215 | SplitInfo=0.9356 | GainRatio=0.0230
# [NUM] SkinThickness | Threshold=29.500 | InfoGain=0.0310 | SplitInfo=0.9166 | GainRatio=0.0339
# [NUM] SkinThickness | Threshold=30.500 | InfoGain=0.0371 | SplitInfo=0.8769 | GainRatio=0.0424
# [NUM] SkinThickness | Threshold=31.500 | InfoGain=0.0509 | SplitInfo=0.8505 | GainRatio=0.0598
# [NUM] SkinThickness | Threshold=32.500 | InfoGain=0.0326 | SplitInfo=0.8211 | GainRatio=0.0397
# [NUM] SkinThickness | Threshold=33.500 | InfoGain=0.0306 | SplitInfo=0.7886 | GainRatio=0.0388
# [NUM] SkinThickness | Threshold=34.500 | InfoGain=0.0363 | SplitInfo=0.7529 | GainRatio=0.0482
# [NUM] SkinThickness | Threshold=35.500 | InfoGain=0.0262 | SplitInfo=0.6929 | GainRatio=0.0378
# [NUM] SkinThickness | Threshold=36.500 | InfoGain=0.0215 | SplitInfo=0.6597 | GainRatio=0.0327
# [NUM] SkinThickness | Threshold=37.500 | InfoGain=0.0172 | SplitInfo=0.6241 | GainRatio=0.0275
# [NUM] SkinThickness | Threshold=38.500 | InfoGain=0.0234 | SplitInfo=0.5990 | GainRatio=0.0390
# [NUM] SkinThickness | Threshold=39.500 | InfoGain=0.0152 | SplitInfo=0.5453 | GainRatio=0.0278
# [NUM] SkinThickness | Threshold=40.500 | InfoGain=0.0218 | SplitInfo=0.5165 | GainRatio=0.0422
# [NUM] SkinThickness | Threshold=41.500 | InfoGain=0.0169 | SplitInfo=0.4380 | GainRatio=0.0386
# [NUM] SkinThickness | Threshold=43.000 | InfoGain=0.0165 | SplitInfo=0.3286 | GainRatio=0.0503
# [NUM] SkinThickness | Threshold=44.500 | InfoGain=0.0122 | SplitInfo=0.2658 | GainRatio=0.0459
# [NUM] SkinThickness | Threshold=45.500 | InfoGain=0.0079 | SplitInfo=0.2432 | GainRatio=0.0326
# [NUM] SkinThickness | Threshold=46.500 | InfoGain=0.0043 | SplitInfo=0.2197 | GainRatio=0.0196
# [NUM] SkinThickness | Threshold=48.500 | InfoGain=0.0001 | SplitInfo=0.1693 | GainRatio=0.0004
# [NUM] SkinThickness | Threshold=50.500 | InfoGain=0.0010 | SplitInfo=0.1420 | GainRatio=0.0071
# [NUM] SkinThickness | Threshold=52.500 | InfoGain=0.0001 | SplitInfo=0.1128 | GainRatio=0.0006
# [NUM] SkinThickness | Threshold=55.000 | InfoGain=0.0005 | SplitInfo=0.0811 | GainRatio=0.0061
# [NUM] SkinThickness | Threshold=58.000 | InfoGain=0.0034 | SplitInfo=0.0456 | GainRatio=0.0742
# [NUM] Insulin | Threshold=9.000 | InfoGain=0.0027 | SplitInfo=0.9995 | GainRatio=0.0027
# [NUM] Insulin | Threshold=20.500 | InfoGain=0.0034 | SplitInfo=0.9991 | GainRatio=0.0034
# [NUM] Insulin | Threshold=29.500 | InfoGain=0.0051 | SplitInfo=0.9978 | GainRatio=0.0051
# [NUM] Insulin | Threshold=36.500 | InfoGain=0.0045 | SplitInfo=0.9959 | GainRatio=0.0045
# [NUM] Insulin | Threshold=37.500 | InfoGain=0.0054 | SplitInfo=0.9947 | GainRatio=0.0055
# [NUM] Insulin | Threshold=39.000 | InfoGain=0.0065 | SplitInfo=0.9934 | GainRatio=0.0065
# [NUM] Insulin | Threshold=44.000 | InfoGain=0.0076 | SplitInfo=0.9920 | GainRatio=0.0076
# [NUM] Insulin | Threshold=48.500 | InfoGain=0.0080 | SplitInfo=0.9867 | GainRatio=0.0081
# [NUM] Insulin | Threshold=49.500 | InfoGain=0.0092 | SplitInfo=0.9846 | GainRatio=0.0094
# [NUM] Insulin | Threshold=50.500 | InfoGain=0.0106 | SplitInfo=0.9824 | GainRatio=0.0108
# [NUM] Insulin | Threshold=52.000 | InfoGain=0.0120 | SplitInfo=0.9801 | GainRatio=0.0123
# [NUM] Insulin | Threshold=53.500 | InfoGain=0.0136 | SplitInfo=0.9776 | GainRatio=0.0139
# [NUM] Insulin | Threshold=54.500 | InfoGain=0.0152 | SplitInfo=0.9749 | GainRatio=0.0156
# [NUM] Insulin | Threshold=56.500 | InfoGain=0.0170 | SplitInfo=0.9721 | GainRatio=0.0175
# [NUM] Insulin | Threshold=60.500 | InfoGain=0.0142 | SplitInfo=0.9692 | GainRatio=0.0147
# [NUM] Insulin | Threshold=63.500 | InfoGain=0.0159 | SplitInfo=0.9661 | GainRatio=0.0165
# [NUM] Insulin | Threshold=67.000 | InfoGain=0.0196 | SplitInfo=0.9594 | GainRatio=0.0205
# [NUM] Insulin | Threshold=70.500 | InfoGain=0.0217 | SplitInfo=0.9558 | GainRatio=0.0227
# [NUM] Insulin | Threshold=73.500 | InfoGain=0.0261 | SplitInfo=0.9482 | GainRatio=0.0275
# [NUM] Insulin | Threshold=77.000 | InfoGain=0.0285 | SplitInfo=0.9442 | GainRatio=0.0301
# [NUM] Insulin | Threshold=80.000 | InfoGain=0.0310 | SplitInfo=0.9400 | GainRatio=0.0330
# [NUM] Insulin | Threshold=82.500 | InfoGain=0.0336 | SplitInfo=0.9356 | GainRatio=0.0359
# [NUM] Insulin | Threshold=85.500 | InfoGain=0.0364 | SplitInfo=0.9311 | GainRatio=0.0391
# [NUM] Insulin | Threshold=89.000 | InfoGain=0.0323 | SplitInfo=0.9264 | GainRatio=0.0349
# [NUM] Insulin | Threshold=91.000 | InfoGain=0.0284 | SplitInfo=0.9216 | GainRatio=0.0309
# [NUM] Insulin | Threshold=93.000 | InfoGain=0.0338 | SplitInfo=0.9114 | GainRatio=0.0370
# [NUM] Insulin | Threshold=95.000 | InfoGain=0.0462 | SplitInfo=0.8891 | GainRatio=0.0519
# [NUM] Insulin | Threshold=97.500 | InfoGain=0.0415 | SplitInfo=0.8831 | GainRatio=0.0470
# [NUM] Insulin | Threshold=99.500 | InfoGain=0.0330 | SplitInfo=0.8706 | GainRatio=0.0379
# [NUM] Insulin | Threshold=102.500 | InfoGain=0.0348 | SplitInfo=0.8505 | GainRatio=0.0409
# [NUM] Insulin | Threshold=107.500 | InfoGain=0.0380 | SplitInfo=0.8434 | GainRatio=0.0450
# [NUM] Insulin | Threshold=112.000 | InfoGain=0.0402 | SplitInfo=0.8211 | GainRatio=0.0490
# [NUM] Insulin | Threshold=114.500 | InfoGain=0.0316 | SplitInfo=0.8052 | GainRatio=0.0392
# [NUM] Insulin | Threshold=117.000 | InfoGain=0.0276 | SplitInfo=0.7970 | GainRatio=0.0346
# [NUM] Insulin | Threshold=122.000 | InfoGain=0.0306 | SplitInfo=0.7886 | GainRatio=0.0388
# [NUM] Insulin | Threshold=126.500 | InfoGain=0.0338 | SplitInfo=0.7800 | GainRatio=0.0433
# [NUM] Insulin | Threshold=129.000 | InfoGain=0.0372 | SplitInfo=0.7712 | GainRatio=0.0483
# [NUM] Insulin | Threshold=132.500 | InfoGain=0.0248 | SplitInfo=0.7435 | GainRatio=0.0334
# [NUM] Insulin | Threshold=137.500 | InfoGain=0.0270 | SplitInfo=0.7138 | GainRatio=0.0378
# [NUM] Insulin | Threshold=141.000 | InfoGain=0.0420 | SplitInfo=0.6710 | GainRatio=0.0626
# [NUM] Insulin | Threshold=143.500 | InfoGain=0.0466 | SplitInfo=0.6597 | GainRatio=0.0707
# [NUM] Insulin | Threshold=145.500 | InfoGain=0.0415 | SplitInfo=0.6481 | GainRatio=0.0641
# [NUM] Insulin | Threshold=149.000 | InfoGain=0.0366 | SplitInfo=0.6362 | GainRatio=0.0576
# [NUM] Insulin | Threshold=153.500 | InfoGain=0.0411 | SplitInfo=0.6241 | GainRatio=0.0659
# [NUM] Insulin | Threshold=155.500 | InfoGain=0.0362 | SplitInfo=0.6117 | GainRatio=0.0591
# [NUM] Insulin | Threshold=158.000 | InfoGain=0.0315 | SplitInfo=0.5990 | GainRatio=0.0525
# [NUM] Insulin | Threshold=164.000 | InfoGain=0.0270 | SplitInfo=0.5861 | GainRatio=0.0461
# [NUM] Insulin | Threshold=171.500 | InfoGain=0.0188 | SplitInfo=0.5592 | GainRatio=0.0337
# [NUM] Insulin | Threshold=175.500 | InfoGain=0.0118 | SplitInfo=0.5311 | GainRatio=0.0222
# [NUM] Insulin | Threshold=184.000 | InfoGain=0.0145 | SplitInfo=0.5165 | GainRatio=0.0282
# [NUM] Insulin | Threshold=198.000 | InfoGain=0.0177 | SplitInfo=0.5016 | GainRatio=0.0353
# [NUM] Insulin | Threshold=205.500 | InfoGain=0.0214 | SplitInfo=0.4863 | GainRatio=0.0440
# [NUM] Insulin | Threshold=208.500 | InfoGain=0.0173 | SplitInfo=0.4706 | GainRatio=0.0367
# [NUM] Insulin | Threshold=215.000 | InfoGain=0.0135 | SplitInfo=0.4545 | GainRatio=0.0296
# [NUM] Insulin | Threshold=222.500 | InfoGain=0.0100 | SplitInfo=0.4380 | GainRatio=0.0228
# [NUM] Insulin | Threshold=226.500 | InfoGain=0.0069 | SplitInfo=0.4210 | GainRatio=0.0164
# [NUM] Insulin | Threshold=229.000 | InfoGain=0.0094 | SplitInfo=0.4036 | GainRatio=0.0234
# [NUM] Insulin | Threshold=232.500 | InfoGain=0.0063 | SplitInfo=0.3857 | GainRatio=0.0164
# [NUM] Insulin | Threshold=237.500 | InfoGain=0.0089 | SplitInfo=0.3672 | GainRatio=0.0244
# [NUM] Insulin | Threshold=242.500 | InfoGain=0.0058 | SplitInfo=0.3482 | GainRatio=0.0166
# [NUM] Insulin | Threshold=257.500 | InfoGain=0.0032 | SplitInfo=0.3286 | GainRatio=0.0096
# [NUM] Insulin | Threshold=277.000 | InfoGain=0.0052 | SplitInfo=0.3084 | GainRatio=0.0170
# [NUM] Insulin | Threshold=284.500 | InfoGain=0.0082 | SplitInfo=0.2875 | GainRatio=0.0284
# [NUM] Insulin | Threshold=292.500 | InfoGain=0.0122 | SplitInfo=0.2658 | GainRatio=0.0459
# [NUM] Insulin | Threshold=302.000 | InfoGain=0.0079 | SplitInfo=0.2432 | GainRatio=0.0326
# [NUM] Insulin | Threshold=314.500 | InfoGain=0.0043 | SplitInfo=0.2197 | GainRatio=0.0196
# [NUM] Insulin | Threshold=333.500 | InfoGain=0.0080 | SplitInfo=0.1951 | GainRatio=0.0410
# [NUM] Insulin | Threshold=413.500 | InfoGain=0.0143 | SplitInfo=0.1693 | GainRatio=0.0844
# [NUM] Insulin | Threshold=490.000 | InfoGain=0.0292 | SplitInfo=0.1420 | GainRatio=0.2056
# [NUM] Insulin | Threshold=519.000 | InfoGain=0.0145 | SplitInfo=0.0811 | GainRatio=0.1783
# [NUM] Insulin | Threshold=694.500 | InfoGain=0.0072 | SplitInfo=0.0456 | GainRatio=0.1579
# [NUM] BMI | Threshold=9.550 | InfoGain=0.0026 | SplitInfo=0.1693 | GainRatio=0.0152
# [NUM] BMI | Threshold=19.250 | InfoGain=0.0045 | SplitInfo=0.1951 | GainRatio=0.0233
# [NUM] BMI | Threshold=19.500 | InfoGain=0.0068 | SplitInfo=0.2197 | GainRatio=0.0309
# [NUM] BMI | Threshold=19.750 | InfoGain=0.0092 | SplitInfo=0.2432 | GainRatio=0.0380
# [NUM] BMI | Threshold=20.150 | InfoGain=0.0118 | SplitInfo=0.2658 | GainRatio=0.0445
# [NUM] BMI | Threshold=20.750 | InfoGain=0.0145 | SplitInfo=0.2875 | GainRatio=0.0506
# [NUM] BMI | Threshold=21.500 | InfoGain=0.0203 | SplitInfo=0.3286 | GainRatio=0.0617
# [NUM] BMI | Threshold=22.050 | InfoGain=0.0233 | SplitInfo=0.3482 | GainRatio=0.0669
# [NUM] BMI | Threshold=22.300 | InfoGain=0.0264 | SplitInfo=0.3672 | GainRatio=0.0718
# [NUM] BMI | Threshold=22.450 | InfoGain=0.0327 | SplitInfo=0.4036 | GainRatio=0.0810
# [NUM] BMI | Threshold=22.550 | InfoGain=0.0359 | SplitInfo=0.4210 | GainRatio=0.0853
# [NUM] BMI | Threshold=22.650 | InfoGain=0.0392 | SplitInfo=0.4380 | GainRatio=0.0896
# [NUM] BMI | Threshold=22.800 | InfoGain=0.0426 | SplitInfo=0.4545 | GainRatio=0.0937
# [NUM] BMI | Threshold=22.950 | InfoGain=0.0304 | SplitInfo=0.4706 | GainRatio=0.0647
# [NUM] BMI | Threshold=23.100 | InfoGain=0.0334 | SplitInfo=0.4863 | GainRatio=0.0687
# [NUM] BMI | Threshold=23.250 | InfoGain=0.0428 | SplitInfo=0.5311 | GainRatio=0.0806
# [NUM] BMI | Threshold=23.550 | InfoGain=0.0327 | SplitInfo=0.5453 | GainRatio=0.0599
# [NUM] BMI | Threshold=23.900 | InfoGain=0.0248 | SplitInfo=0.5592 | GainRatio=0.0443
# [NUM] BMI | Threshold=24.100 | InfoGain=0.0274 | SplitInfo=0.5728 | GainRatio=0.0478
# [NUM] BMI | Threshold=24.250 | InfoGain=0.0300 | SplitInfo=0.5861 | GainRatio=0.0512
# [NUM] BMI | Threshold=24.350 | InfoGain=0.0328 | SplitInfo=0.5990 | GainRatio=0.0547
# [NUM] BMI | Threshold=24.500 | InfoGain=0.0384 | SplitInfo=0.6241 | GainRatio=0.0616
# [NUM] BMI | Threshold=24.650 | InfoGain=0.0444 | SplitInfo=0.6481 | GainRatio=0.0685
# [NUM] BMI | Threshold=24.750 | InfoGain=0.0506 | SplitInfo=0.6710 | GainRatio=0.0754
# [NUM] BMI | Threshold=24.900 | InfoGain=0.0538 | SplitInfo=0.6821 | GainRatio=0.0788
# [NUM] BMI | Threshold=25.100 | InfoGain=0.0603 | SplitInfo=0.7035 | GainRatio=0.0857
# [NUM] BMI | Threshold=25.300 | InfoGain=0.0637 | SplitInfo=0.7138 | GainRatio=0.0892
# [NUM] BMI | Threshold=25.500 | InfoGain=0.0671 | SplitInfo=0.7239 | GainRatio=0.0927
# [NUM] BMI | Threshold=25.700 | InfoGain=0.0705 | SplitInfo=0.7338 | GainRatio=0.0961
# [NUM] BMI | Threshold=25.950 | InfoGain=0.0604 | SplitInfo=0.7435 | GainRatio=0.0812
# [NUM] BMI | Threshold=26.300 | InfoGain=0.0637 | SplitInfo=0.7529 | GainRatio=0.0846
# [NUM] BMI | Threshold=26.550 | InfoGain=0.0670 | SplitInfo=0.7622 | GainRatio=0.0879
# [NUM] BMI | Threshold=26.700 | InfoGain=0.0739 | SplitInfo=0.7800 | GainRatio=0.0948
# [NUM] BMI | Threshold=26.950 | InfoGain=0.0811 | SplitInfo=0.7970 | GainRatio=0.1017
# [NUM] BMI | Threshold=27.200 | InfoGain=0.0847 | SplitInfo=0.8052 | GainRatio=0.1052
# [NUM] BMI | Threshold=27.350 | InfoGain=0.0885 | SplitInfo=0.8133 | GainRatio=0.1088
# [NUM] BMI | Threshold=27.500 | InfoGain=0.0922 | SplitInfo=0.8211 | GainRatio=0.1123
# [NUM] BMI | Threshold=27.650 | InfoGain=0.1000 | SplitInfo=0.8362 | GainRatio=0.1195
# [NUM] BMI | Threshold=27.800 | InfoGain=0.1039 | SplitInfo=0.8434 | GainRatio=0.1232
# [NUM] BMI | Threshold=27.950 | InfoGain=0.0826 | SplitInfo=0.8574 | GainRatio=0.0963
# [NUM] BMI | Threshold=28.050 | InfoGain=0.0862 | SplitInfo=0.8641 | GainRatio=0.0998
# [NUM] BMI | Threshold=28.150 | InfoGain=0.0899 | SplitInfo=0.8706 | GainRatio=0.1033
# [NUM] BMI | Threshold=28.300 | InfoGain=0.0937 | SplitInfo=0.8769 | GainRatio=0.1069
# [NUM] BMI | Threshold=28.500 | InfoGain=0.0976 | SplitInfo=0.8831 | GainRatio=0.1105
# [NUM] BMI | Threshold=28.650 | InfoGain=0.1015 | SplitInfo=0.8891 | GainRatio=0.1141
# [NUM] BMI | Threshold=28.800 | InfoGain=0.1136 | SplitInfo=0.9061 | GainRatio=0.1253
# [NUM] BMI | Threshold=28.950 | InfoGain=0.1220 | SplitInfo=0.9166 | GainRatio=0.1330
# [NUM] BMI | Threshold=29.150 | InfoGain=0.1195 | SplitInfo=0.9311 | GainRatio=0.1283
# [NUM] BMI | Threshold=29.400 | InfoGain=0.1238 | SplitInfo=0.9356 | GainRatio=0.1323
# [NUM] BMI | Threshold=29.550 | InfoGain=0.1281 | SplitInfo=0.9400 | GainRatio=0.1363
# [NUM] BMI | Threshold=29.650 | InfoGain=0.1218 | SplitInfo=0.9482 | GainRatio=0.1284
# [NUM] BMI | Threshold=29.800 | InfoGain=0.1290 | SplitInfo=0.9661 | GainRatio=0.1335
# [NUM] BMI | Threshold=29.950 | InfoGain=0.1190 | SplitInfo=0.9692 | GainRatio=0.1228
# [NUM] BMI | Threshold=30.050 | InfoGain=0.1097 | SplitInfo=0.9721 | GainRatio=0.1128
# [NUM] BMI | Threshold=30.250 | InfoGain=0.0927 | SplitInfo=0.9776 | GainRatio=0.0949
# [NUM] BMI | Threshold=30.450 | InfoGain=0.0850 | SplitInfo=0.9801 | GainRatio=0.0867
# [NUM] BMI | Threshold=30.650 | InfoGain=0.0743 | SplitInfo=0.9867 | GainRatio=0.0753
# [NUM] BMI | Threshold=30.900 | InfoGain=0.0711 | SplitInfo=0.9903 | GainRatio=0.0718
# [NUM] BMI | Threshold=31.050 | InfoGain=0.0648 | SplitInfo=0.9920 | GainRatio=0.0653
# [NUM] BMI | Threshold=31.150 | InfoGain=0.0588 | SplitInfo=0.9934 | GainRatio=0.0592
# [NUM] BMI | Threshold=31.400 | InfoGain=0.0625 | SplitInfo=0.9978 | GainRatio=0.0626
# [NUM] BMI | Threshold=31.750 | InfoGain=0.0491 | SplitInfo=0.9998 | GainRatio=0.0491
# [NUM] BMI | Threshold=31.950 | InfoGain=0.0521 | SplitInfo=1.0000 | GainRatio=0.0521
# [NUM] BMI | Threshold=32.200 | InfoGain=0.0529 | SplitInfo=0.9995 | GainRatio=0.0529
# [NUM] BMI | Threshold=32.450 | InfoGain=0.0508 | SplitInfo=0.9985 | GainRatio=0.0508
# [NUM] BMI | Threshold=32.550 | InfoGain=0.0517 | SplitInfo=0.9959 | GainRatio=0.0520
# [NUM] BMI | Threshold=32.650 | InfoGain=0.0549 | SplitInfo=0.9947 | GainRatio=0.0552
# [NUM] BMI | Threshold=32.750 | InfoGain=0.0497 | SplitInfo=0.9934 | GainRatio=0.0501
# [NUM] BMI | Threshold=32.850 | InfoGain=0.0509 | SplitInfo=0.9886 | GainRatio=0.0515
# [NUM] BMI | Threshold=33.000 | InfoGain=0.0370 | SplitInfo=0.9824 | GainRatio=0.0377
# [NUM] BMI | Threshold=33.150 | InfoGain=0.0397 | SplitInfo=0.9801 | GainRatio=0.0405
# [NUM] BMI | Threshold=33.250 | InfoGain=0.0425 | SplitInfo=0.9776 | GainRatio=0.0435
# [NUM] BMI | Threshold=33.450 | InfoGain=0.0325 | SplitInfo=0.9661 | GainRatio=0.0336
# [NUM] BMI | Threshold=33.650 | InfoGain=0.0311 | SplitInfo=0.9594 | GainRatio=0.0324
# [NUM] BMI | Threshold=33.750 | InfoGain=0.0323 | SplitInfo=0.9482 | GainRatio=0.0341
# [NUM] BMI | Threshold=33.850 | InfoGain=0.0350 | SplitInfo=0.9442 | GainRatio=0.0370
# [NUM] BMI | Threshold=33.950 | InfoGain=0.0378 | SplitInfo=0.9400 | GainRatio=0.0402
# [NUM] BMI | Threshold=34.050 | InfoGain=0.0351 | SplitInfo=0.9216 | GainRatio=0.0380
# [NUM] BMI | Threshold=34.150 | InfoGain=0.0379 | SplitInfo=0.9166 | GainRatio=0.0414
# [NUM] BMI | Threshold=34.250 | InfoGain=0.0410 | SplitInfo=0.9114 | GainRatio=0.0450
# [NUM] BMI | Threshold=34.400 | InfoGain=0.0397 | SplitInfo=0.9006 | GainRatio=0.0440
# [NUM] BMI | Threshold=34.550 | InfoGain=0.0313 | SplitInfo=0.8891 | GainRatio=0.0352
# [NUM] BMI | Threshold=34.650 | InfoGain=0.0275 | SplitInfo=0.8831 | GainRatio=0.0311
# [NUM] BMI | Threshold=34.750 | InfoGain=0.0301 | SplitInfo=0.8769 | GainRatio=0.0344
# [NUM] BMI | Threshold=34.850 | InfoGain=0.0264 | SplitInfo=0.8706 | GainRatio=0.0303
# [NUM] BMI | Threshold=35.000 | InfoGain=0.0290 | SplitInfo=0.8641 | GainRatio=0.0336
# [NUM] BMI | Threshold=35.200 | InfoGain=0.0318 | SplitInfo=0.8574 | GainRatio=0.0371
# [NUM] BMI | Threshold=35.350 | InfoGain=0.0348 | SplitInfo=0.8505 | GainRatio=0.0409
# [NUM] BMI | Threshold=35.650 | InfoGain=0.0337 | SplitInfo=0.8362 | GainRatio=0.0403
# [NUM] BMI | Threshold=35.950 | InfoGain=0.0296 | SplitInfo=0.8287 | GainRatio=0.0358
# [NUM] BMI | Threshold=36.300 | InfoGain=0.0326 | SplitInfo=0.8211 | GainRatio=0.0397
# [NUM] BMI | Threshold=36.750 | InfoGain=0.0316 | SplitInfo=0.8052 | GainRatio=0.0392
# [NUM] BMI | Threshold=37.000 | InfoGain=0.0348 | SplitInfo=0.7970 | GainRatio=0.0436
# [NUM] BMI | Threshold=37.150 | InfoGain=0.0266 | SplitInfo=0.7800 | GainRatio=0.0342
# [NUM] BMI | Threshold=37.300 | InfoGain=0.0296 | SplitInfo=0.7712 | GainRatio=0.0384
# [NUM] BMI | Threshold=37.500 | InfoGain=0.0287 | SplitInfo=0.7529 | GainRatio=0.0381
# [NUM] BMI | Threshold=37.650 | InfoGain=0.0320 | SplitInfo=0.7435 | GainRatio=0.0430
# [NUM] BMI | Threshold=37.850 | InfoGain=0.0311 | SplitInfo=0.7239 | GainRatio=0.0430
# [NUM] BMI | Threshold=38.100 | InfoGain=0.0270 | SplitInfo=0.7138 | GainRatio=0.0378
# [NUM] BMI | Threshold=38.250 | InfoGain=0.0231 | SplitInfo=0.7035 | GainRatio=0.0329
# [NUM] BMI | Threshold=38.400 | InfoGain=0.0262 | SplitInfo=0.6929 | GainRatio=0.0378
# [NUM] BMI | Threshold=38.750 | InfoGain=0.0295 | SplitInfo=0.6821 | GainRatio=0.0433
# [NUM] BMI | Threshold=39.050 | InfoGain=0.0254 | SplitInfo=0.6710 | GainRatio=0.0379
# [NUM] BMI | Threshold=39.200 | InfoGain=0.0179 | SplitInfo=0.6481 | GainRatio=0.0277
# [NUM] BMI | Threshold=39.350 | InfoGain=0.0208 | SplitInfo=0.6362 | GainRatio=0.0327
# [NUM] BMI | Threshold=39.450 | InfoGain=0.0139 | SplitInfo=0.6117 | GainRatio=0.0226
# [NUM] BMI | Threshold=39.550 | InfoGain=0.0165 | SplitInfo=0.5990 | GainRatio=0.0275
# [NUM] BMI | Threshold=39.700 | InfoGain=0.0194 | SplitInfo=0.5861 | GainRatio=0.0332
# [NUM] BMI | Threshold=40.000 | InfoGain=0.0158 | SplitInfo=0.5728 | GainRatio=0.0276
# [NUM] BMI | Threshold=40.350 | InfoGain=0.0188 | SplitInfo=0.5592 | GainRatio=0.0337
# [NUM] BMI | Threshold=40.550 | InfoGain=0.0222 | SplitInfo=0.5453 | GainRatio=0.0408
# [NUM] BMI | Threshold=40.750 | InfoGain=0.0261 | SplitInfo=0.5311 | GainRatio=0.0492
# [NUM] BMI | Threshold=41.200 | InfoGain=0.0218 | SplitInfo=0.5165 | GainRatio=0.0422
# [NUM] BMI | Threshold=41.750 | InfoGain=0.0258 | SplitInfo=0.5016 | GainRatio=0.0515
# [NUM] BMI | Threshold=42.350 | InfoGain=0.0214 | SplitInfo=0.4863 | GainRatio=0.0440
# [NUM] BMI | Threshold=42.800 | InfoGain=0.0257 | SplitInfo=0.4706 | GainRatio=0.0545
# [NUM] BMI | Threshold=43.000 | InfoGain=0.0306 | SplitInfo=0.4545 | GainRatio=0.0674
# [NUM] BMI | Threshold=43.150 | InfoGain=0.0257 | SplitInfo=0.4380 | GainRatio=0.0586
# [NUM] BMI | Threshold=43.250 | InfoGain=0.0210 | SplitInfo=0.4210 | GainRatio=0.0498
# [NUM] BMI | Threshold=43.350 | InfoGain=0.0259 | SplitInfo=0.4036 | GainRatio=0.0641
# [NUM] BMI | Threshold=43.450 | InfoGain=0.0210 | SplitInfo=0.3857 | GainRatio=0.0545
# [NUM] BMI | Threshold=43.850 | InfoGain=0.0264 | SplitInfo=0.3672 | GainRatio=0.0720
# [NUM] BMI | Threshold=44.600 | InfoGain=0.0332 | SplitInfo=0.3482 | GainRatio=0.0952
# [NUM] BMI | Threshold=45.200 | InfoGain=0.0418 | SplitInfo=0.3286 | GainRatio=0.1273
# [NUM] BMI | Threshold=45.600 | InfoGain=0.0355 | SplitInfo=0.3084 | GainRatio=0.1151
# [NUM] BMI | Threshold=46.250 | InfoGain=0.0294 | SplitInfo=0.2875 | GainRatio=0.1021
# [NUM] BMI | Threshold=46.750 | InfoGain=0.0398 | SplitInfo=0.2658 | GainRatio=0.1496
# [NUM] BMI | Threshold=47.350 | InfoGain=0.0594 | SplitInfo=0.2432 | GainRatio=0.2444
# [NUM] BMI | Threshold=48.350 | InfoGain=0.0518 | SplitInfo=0.2197 | GainRatio=0.2357
# [NUM] BMI | Threshold=49.250 | InfoGain=0.0442 | SplitInfo=0.1951 | GainRatio=0.2264
# [NUM] BMI | Threshold=49.850 | InfoGain=0.0367 | SplitInfo=0.1693 | GainRatio=0.2165
# [NUM] BMI | Threshold=51.150 | InfoGain=0.0292 | SplitInfo=0.1420 | GainRatio=0.2056
# [NUM] BMI | Threshold=52.750 | InfoGain=0.0218 | SplitInfo=0.1128 | GainRatio=0.1932
# [NUM] BMI | Threshold=54.100 | InfoGain=0.0145 | SplitInfo=0.0811 | GainRatio=0.1783
# [NUM] BMI | Threshold=61.050 | InfoGain=0.0072 | SplitInfo=0.0456 | GainRatio=0.1579
# [NUM] DiabetesPedigreeFunction | Threshold=0.085 | InfoGain=0.0034 | SplitInfo=0.0456 | GainRatio=0.0742
# [NUM] DiabetesPedigreeFunction | Threshold=0.086 | InfoGain=0.0068 | SplitInfo=0.0811 | GainRatio=0.0836
# [NUM] DiabetesPedigreeFunction | Threshold=0.092 | InfoGain=0.0102 | SplitInfo=0.1128 | GainRatio=0.0905
# [NUM] DiabetesPedigreeFunction | Threshold=0.099 | InfoGain=0.0137 | SplitInfo=0.1420 | GainRatio=0.0962
# [NUM] DiabetesPedigreeFunction | Threshold=0.116 | InfoGain=0.0171 | SplitInfo=0.1693 | GainRatio=0.1012
# [NUM] DiabetesPedigreeFunction | Threshold=0.132 | InfoGain=0.0206 | SplitInfo=0.1951 | GainRatio=0.1057
# [NUM] DiabetesPedigreeFunction | Threshold=0.135 | InfoGain=0.0241 | SplitInfo=0.2197 | GainRatio=0.1099
# [NUM] DiabetesPedigreeFunction | Threshold=0.137 | InfoGain=0.0277 | SplitInfo=0.2432 | GainRatio=0.1138
# [NUM] DiabetesPedigreeFunction | Threshold=0.139 | InfoGain=0.0118 | SplitInfo=0.2658 | GainRatio=0.0445
# [NUM] DiabetesPedigreeFunction | Threshold=0.141 | InfoGain=0.0174 | SplitInfo=0.3084 | GainRatio=0.0563
# [NUM] DiabetesPedigreeFunction | Threshold=0.147 | InfoGain=0.0203 | SplitInfo=0.3286 | GainRatio=0.0617
# [NUM] DiabetesPedigreeFunction | Threshold=0.155 | InfoGain=0.0116 | SplitInfo=0.3482 | GainRatio=0.0334
# [NUM] DiabetesPedigreeFunction | Threshold=0.159 | InfoGain=0.0063 | SplitInfo=0.3672 | GainRatio=0.0171
# [NUM] DiabetesPedigreeFunction | Threshold=0.162 | InfoGain=0.0081 | SplitInfo=0.3857 | GainRatio=0.0210
# [NUM] DiabetesPedigreeFunction | Threshold=0.166 | InfoGain=0.0101 | SplitInfo=0.4036 | GainRatio=0.0250
# [NUM] DiabetesPedigreeFunction | Threshold=0.170 | InfoGain=0.0144 | SplitInfo=0.4380 | GainRatio=0.0330
# [NUM] DiabetesPedigreeFunction | Threshold=0.175 | InfoGain=0.0168 | SplitInfo=0.4545 | GainRatio=0.0369
# [NUM] DiabetesPedigreeFunction | Threshold=0.178 | InfoGain=0.0192 | SplitInfo=0.4706 | GainRatio=0.0409
# [NUM] DiabetesPedigreeFunction | Threshold=0.179 | InfoGain=0.0218 | SplitInfo=0.4863 | GainRatio=0.0447
# [NUM] DiabetesPedigreeFunction | Threshold=0.181 | InfoGain=0.0153 | SplitInfo=0.5016 | GainRatio=0.0304
# [NUM] DiabetesPedigreeFunction | Threshold=0.184 | InfoGain=0.0175 | SplitInfo=0.5165 | GainRatio=0.0339
# [NUM] DiabetesPedigreeFunction | Threshold=0.186 | InfoGain=0.0198 | SplitInfo=0.5311 | GainRatio=0.0374
# [NUM] DiabetesPedigreeFunction | Threshold=0.188 | InfoGain=0.0223 | SplitInfo=0.5453 | GainRatio=0.0408
# [NUM] DiabetesPedigreeFunction | Threshold=0.189 | InfoGain=0.0248 | SplitInfo=0.5592 | GainRatio=0.0443
# [NUM] DiabetesPedigreeFunction | Threshold=0.190 | InfoGain=0.0274 | SplitInfo=0.5728 | GainRatio=0.0478
# [NUM] DiabetesPedigreeFunction | Threshold=0.191 | InfoGain=0.0300 | SplitInfo=0.5861 | GainRatio=0.0512
# [NUM] DiabetesPedigreeFunction | Threshold=0.192 | InfoGain=0.0328 | SplitInfo=0.5990 | GainRatio=0.0547
# [NUM] DiabetesPedigreeFunction | Threshold=0.196 | InfoGain=0.0356 | SplitInfo=0.6117 | GainRatio=0.0581
# [NUM] DiabetesPedigreeFunction | Threshold=0.200 | InfoGain=0.0281 | SplitInfo=0.6241 | GainRatio=0.0450
# [NUM] DiabetesPedigreeFunction | Threshold=0.202 | InfoGain=0.0307 | SplitInfo=0.6362 | GainRatio=0.0482
# [NUM] DiabetesPedigreeFunction | Threshold=0.204 | InfoGain=0.0334 | SplitInfo=0.6481 | GainRatio=0.0515
# [NUM] DiabetesPedigreeFunction | Threshold=0.204 | InfoGain=0.0361 | SplitInfo=0.6597 | GainRatio=0.0547
# [NUM] DiabetesPedigreeFunction | Threshold=0.206 | InfoGain=0.0291 | SplitInfo=0.6710 | GainRatio=0.0434
# [NUM] DiabetesPedigreeFunction | Threshold=0.212 | InfoGain=0.0317 | SplitInfo=0.6821 | GainRatio=0.0465
# [NUM] DiabetesPedigreeFunction | Threshold=0.219 | InfoGain=0.0343 | SplitInfo=0.6929 | GainRatio=0.0495
# [NUM] DiabetesPedigreeFunction | Threshold=0.222 | InfoGain=0.0279 | SplitInfo=0.7035 | GainRatio=0.0397
# [NUM] DiabetesPedigreeFunction | Threshold=0.225 | InfoGain=0.0304 | SplitInfo=0.7138 | GainRatio=0.0426
# [NUM] DiabetesPedigreeFunction | Threshold=0.228 | InfoGain=0.0247 | SplitInfo=0.7239 | GainRatio=0.0341
# [NUM] DiabetesPedigreeFunction | Threshold=0.230 | InfoGain=0.0270 | SplitInfo=0.7338 | GainRatio=0.0368
# [NUM] DiabetesPedigreeFunction | Threshold=0.232 | InfoGain=0.0294 | SplitInfo=0.7435 | GainRatio=0.0395
# [NUM] DiabetesPedigreeFunction | Threshold=0.233 | InfoGain=0.0240 | SplitInfo=0.7529 | GainRatio=0.0319
# [NUM] DiabetesPedigreeFunction | Threshold=0.236 | InfoGain=0.0263 | SplitInfo=0.7622 | GainRatio=0.0345
# [NUM] DiabetesPedigreeFunction | Threshold=0.240 | InfoGain=0.0310 | SplitInfo=0.7800 | GainRatio=0.0397
# [NUM] DiabetesPedigreeFunction | Threshold=0.244 | InfoGain=0.0334 | SplitInfo=0.7886 | GainRatio=0.0424
# [NUM] DiabetesPedigreeFunction | Threshold=0.246 | InfoGain=0.0360 | SplitInfo=0.7970 | GainRatio=0.0451
# [NUM] DiabetesPedigreeFunction | Threshold=0.247 | InfoGain=0.0303 | SplitInfo=0.8052 | GainRatio=0.0376
# [NUM] DiabetesPedigreeFunction | Threshold=0.251 | InfoGain=0.0275 | SplitInfo=0.8211 | GainRatio=0.0335
# [NUM] DiabetesPedigreeFunction | Threshold=0.255 | InfoGain=0.0151 | SplitInfo=0.8434 | GainRatio=0.0179
# [NUM] DiabetesPedigreeFunction | Threshold=0.256 | InfoGain=0.0168 | SplitInfo=0.8505 | GainRatio=0.0198
# [NUM] DiabetesPedigreeFunction | Threshold=0.257 | InfoGain=0.0187 | SplitInfo=0.8574 | GainRatio=0.0218
# [NUM] DiabetesPedigreeFunction | Threshold=0.258 | InfoGain=0.0151 | SplitInfo=0.8641 | GainRatio=0.0175
# [NUM] DiabetesPedigreeFunction | Threshold=0.259 | InfoGain=0.0136 | SplitInfo=0.8769 | GainRatio=0.0155
# [NUM] DiabetesPedigreeFunction | Threshold=0.261 | InfoGain=0.0152 | SplitInfo=0.8831 | GainRatio=0.0172
# [NUM] DiabetesPedigreeFunction | Threshold=0.262 | InfoGain=0.0187 | SplitInfo=0.8950 | GainRatio=0.0209
# [NUM] DiabetesPedigreeFunction | Threshold=0.263 | InfoGain=0.0206 | SplitInfo=0.9006 | GainRatio=0.0228
# [NUM] DiabetesPedigreeFunction | Threshold=0.265 | InfoGain=0.0170 | SplitInfo=0.9061 | GainRatio=0.0188
# [NUM] DiabetesPedigreeFunction | Threshold=0.268 | InfoGain=0.0188 | SplitInfo=0.9114 | GainRatio=0.0206
# [NUM] DiabetesPedigreeFunction | Threshold=0.269 | InfoGain=0.0226 | SplitInfo=0.9216 | GainRatio=0.0245
# [NUM] DiabetesPedigreeFunction | Threshold=0.271 | InfoGain=0.0156 | SplitInfo=0.9311 | GainRatio=0.0168
# [NUM] DiabetesPedigreeFunction | Threshold=0.272 | InfoGain=0.0173 | SplitInfo=0.9356 | GainRatio=0.0185
# [NUM] DiabetesPedigreeFunction | Threshold=0.275 | InfoGain=0.0142 | SplitInfo=0.9400 | GainRatio=0.0151
# [NUM] DiabetesPedigreeFunction | Threshold=0.278 | InfoGain=0.0115 | SplitInfo=0.9442 | GainRatio=0.0121
# [NUM] DiabetesPedigreeFunction | Threshold=0.280 | InfoGain=0.0090 | SplitInfo=0.9482 | GainRatio=0.0095
# [NUM] DiabetesPedigreeFunction | Threshold=0.284 | InfoGain=0.0103 | SplitInfo=0.9521 | GainRatio=0.0108
# [NUM] DiabetesPedigreeFunction | Threshold=0.286 | InfoGain=0.0117 | SplitInfo=0.9558 | GainRatio=0.0122
# [NUM] DiabetesPedigreeFunction | Threshold=0.290 | InfoGain=0.0132 | SplitInfo=0.9594 | GainRatio=0.0137
# [NUM] DiabetesPedigreeFunction | Threshold=0.296 | InfoGain=0.0163 | SplitInfo=0.9661 | GainRatio=0.0169
# [NUM] DiabetesPedigreeFunction | Threshold=0.301 | InfoGain=0.0181 | SplitInfo=0.9692 | GainRatio=0.0186
# [NUM] DiabetesPedigreeFunction | Threshold=0.304 | InfoGain=0.0198 | SplitInfo=0.9721 | GainRatio=0.0204
# [NUM] DiabetesPedigreeFunction | Threshold=0.306 | InfoGain=0.0217 | SplitInfo=0.9749 | GainRatio=0.0223
# [NUM] DiabetesPedigreeFunction | Threshold=0.312 | InfoGain=0.0237 | SplitInfo=0.9776 | GainRatio=0.0242
# [NUM] DiabetesPedigreeFunction | Threshold=0.319 | InfoGain=0.0257 | SplitInfo=0.9801 | GainRatio=0.0262
# [NUM] DiabetesPedigreeFunction | Threshold=0.321 | InfoGain=0.0221 | SplitInfo=0.9824 | GainRatio=0.0225
# [NUM] DiabetesPedigreeFunction | Threshold=0.324 | InfoGain=0.0240 | SplitInfo=0.9846 | GainRatio=0.0244
# [NUM] DiabetesPedigreeFunction | Threshold=0.325 | InfoGain=0.0261 | SplitInfo=0.9867 | GainRatio=0.0264
# [NUM] DiabetesPedigreeFunction | Threshold=0.330 | InfoGain=0.0224 | SplitInfo=0.9886 | GainRatio=0.0227
# [NUM] DiabetesPedigreeFunction | Threshold=0.335 | InfoGain=0.0244 | SplitInfo=0.9903 | GainRatio=0.0247
# [NUM] DiabetesPedigreeFunction | Threshold=0.337 | InfoGain=0.0265 | SplitInfo=0.9920 | GainRatio=0.0267
# [NUM] DiabetesPedigreeFunction | Threshold=0.340 | InfoGain=0.0249 | SplitInfo=0.9947 | GainRatio=0.0250
# [NUM] DiabetesPedigreeFunction | Threshold=0.343 | InfoGain=0.0270 | SplitInfo=0.9959 | GainRatio=0.0271
# [NUM] DiabetesPedigreeFunction | Threshold=0.347 | InfoGain=0.0233 | SplitInfo=0.9969 | GainRatio=0.0234
# [NUM] DiabetesPedigreeFunction | Threshold=0.353 | InfoGain=0.0254 | SplitInfo=0.9978 | GainRatio=0.0254
# [NUM] DiabetesPedigreeFunction | Threshold=0.358 | InfoGain=0.0239 | SplitInfo=0.9991 | GainRatio=0.0239
# [NUM] DiabetesPedigreeFunction | Threshold=0.364 | InfoGain=0.0174 | SplitInfo=0.9998 | GainRatio=0.0174
# [NUM] DiabetesPedigreeFunction | Threshold=0.369 | InfoGain=0.0192 | SplitInfo=1.0000 | GainRatio=0.0192
# [NUM] DiabetesPedigreeFunction | Threshold=0.372 | InfoGain=0.0230 | SplitInfo=0.9998 | GainRatio=0.0230
# [NUM] DiabetesPedigreeFunction | Threshold=0.378 | InfoGain=0.0250 | SplitInfo=0.9995 | GainRatio=0.0250
# [NUM] DiabetesPedigreeFunction | Threshold=0.383 | InfoGain=0.0272 | SplitInfo=0.9991 | GainRatio=0.0272
# [NUM] DiabetesPedigreeFunction | Threshold=0.386 | InfoGain=0.0236 | SplitInfo=0.9985 | GainRatio=0.0236
# [NUM] DiabetesPedigreeFunction | Threshold=0.390 | InfoGain=0.0257 | SplitInfo=0.9978 | GainRatio=0.0258
# [NUM] DiabetesPedigreeFunction | Threshold=0.393 | InfoGain=0.0302 | SplitInfo=0.9959 | GainRatio=0.0303
# [NUM] DiabetesPedigreeFunction | Threshold=0.396 | InfoGain=0.0264 | SplitInfo=0.9947 | GainRatio=0.0266
# [NUM] DiabetesPedigreeFunction | Threshold=0.397 | InfoGain=0.0287 | SplitInfo=0.9934 | GainRatio=0.0289
# [NUM] DiabetesPedigreeFunction | Threshold=0.399 | InfoGain=0.0250 | SplitInfo=0.9920 | GainRatio=0.0252
# [NUM] DiabetesPedigreeFunction | Threshold=0.401 | InfoGain=0.0272 | SplitInfo=0.9903 | GainRatio=0.0275
# [NUM] DiabetesPedigreeFunction | Threshold=0.404 | InfoGain=0.0237 | SplitInfo=0.9886 | GainRatio=0.0240
# [NUM] DiabetesPedigreeFunction | Threshold=0.407 | InfoGain=0.0258 | SplitInfo=0.9867 | GainRatio=0.0262
# [NUM] DiabetesPedigreeFunction | Threshold=0.415 | InfoGain=0.0281 | SplitInfo=0.9846 | GainRatio=0.0285
# [NUM] DiabetesPedigreeFunction | Threshold=0.426 | InfoGain=0.0304 | SplitInfo=0.9824 | GainRatio=0.0310
# [NUM] DiabetesPedigreeFunction | Threshold=0.438 | InfoGain=0.0329 | SplitInfo=0.9801 | GainRatio=0.0335
# [NUM] DiabetesPedigreeFunction | Threshold=0.447 | InfoGain=0.0381 | SplitInfo=0.9749 | GainRatio=0.0391
# [NUM] DiabetesPedigreeFunction | Threshold=0.452 | InfoGain=0.0339 | SplitInfo=0.9721 | GainRatio=0.0349
# [NUM] DiabetesPedigreeFunction | Threshold=0.455 | InfoGain=0.0366 | SplitInfo=0.9692 | GainRatio=0.0377
# [NUM] DiabetesPedigreeFunction | Threshold=0.462 | InfoGain=0.0393 | SplitInfo=0.9661 | GainRatio=0.0407
# [NUM] DiabetesPedigreeFunction | Threshold=0.469 | InfoGain=0.0351 | SplitInfo=0.9628 | GainRatio=0.0365
# [NUM] DiabetesPedigreeFunction | Threshold=0.477 | InfoGain=0.0378 | SplitInfo=0.9594 | GainRatio=0.0394
# [NUM] DiabetesPedigreeFunction | Threshold=0.485 | InfoGain=0.0337 | SplitInfo=0.9558 | GainRatio=0.0352
# [NUM] DiabetesPedigreeFunction | Threshold=0.489 | InfoGain=0.0364 | SplitInfo=0.9521 | GainRatio=0.0382
# [NUM] DiabetesPedigreeFunction | Threshold=0.493 | InfoGain=0.0392 | SplitInfo=0.9482 | GainRatio=0.0413
# [NUM] DiabetesPedigreeFunction | Threshold=0.495 | InfoGain=0.0422 | SplitInfo=0.9442 | GainRatio=0.0447
# [NUM] DiabetesPedigreeFunction | Threshold=0.499 | InfoGain=0.0378 | SplitInfo=0.9400 | GainRatio=0.0402
# [NUM] DiabetesPedigreeFunction | Threshold=0.508 | InfoGain=0.0336 | SplitInfo=0.9356 | GainRatio=0.0359
# [NUM] DiabetesPedigreeFunction | Threshold=0.519 | InfoGain=0.0364 | SplitInfo=0.9311 | GainRatio=0.0391
# [NUM] DiabetesPedigreeFunction | Threshold=0.528 | InfoGain=0.0393 | SplitInfo=0.9264 | GainRatio=0.0424
# [NUM] DiabetesPedigreeFunction | Threshold=0.530 | InfoGain=0.0351 | SplitInfo=0.9216 | GainRatio=0.0380
# [NUM] DiabetesPedigreeFunction | Threshold=0.534 | InfoGain=0.0379 | SplitInfo=0.9166 | GainRatio=0.0414
# [NUM] DiabetesPedigreeFunction | Threshold=0.538 | InfoGain=0.0338 | SplitInfo=0.9114 | GainRatio=0.0370
# [NUM] DiabetesPedigreeFunction | Threshold=0.540 | InfoGain=0.0298 | SplitInfo=0.9061 | GainRatio=0.0329
# [NUM] DiabetesPedigreeFunction | Threshold=0.542 | InfoGain=0.0261 | SplitInfo=0.9006 | GainRatio=0.0290
# [NUM] DiabetesPedigreeFunction | Threshold=0.544 | InfoGain=0.0226 | SplitInfo=0.8950 | GainRatio=0.0252
# ...
# [NUM] Pregnancies | Threshold=6.000 | InfoGain=0.0011 | SplitInfo=0.9852 | GainRatio=0.0012
# [NUM] Pregnancies | Threshold=7.500 | InfoGain=0.0477 | SplitInfo=0.9403 | GainRatio=0.0507
# [NUM] Pregnancies | Threshold=8.500 | InfoGain=0.0165 | SplitInfo=0.5917 | GainRatio=0.0279
# [NUM] Pregnancies | Threshold=9.500 | InfoGain=0.0079 | SplitInfo=0.3712 | GainRatio=0.0214
# [NUM] Pregnancies | Threshold=13.500 | InfoGain=0.0039 | SplitInfo=0.2223 | GainRatio=0.0175
# [NUM] BloodPressure | Threshold=57.000 | InfoGain=0.0039 | SplitInfo=0.2223 | GainRatio=0.0175
# [NUM] BloodPressure | Threshold=61.000 | InfoGain=0.0079 | SplitInfo=0.3712 | GainRatio=0.0214
# [NUM] BloodPressure | Threshold=63.000 | InfoGain=0.0121 | SplitInfo=0.4912 | GainRatio=0.0247
# [NUM] BloodPressure | Threshold=65.000 | InfoGain=0.1555 | SplitInfo=0.8113 | GainRatio=0.1916
# [NUM] BloodPressure | Threshold=67.000 | InfoGain=0.1256 | SplitInfo=0.9059 | GainRatio=0.1386
# [NUM] BloodPressure | Threshold=69.000 | InfoGain=0.0927 | SplitInfo=0.9852 | GainRatio=0.0940
# [NUM] BloodPressure | Threshold=71.000 | InfoGain=0.0754 | SplitInfo=1.0000 | GainRatio=0.0754
# [NUM] BloodPressure | Threshold=73.000 | InfoGain=0.0418 | SplitInfo=0.9059 | GainRatio=0.0462
# [NUM] BloodPressure | Threshold=75.000 | InfoGain=0.0362 | SplitInfo=0.8631 | GainRatio=0.0420
# [NUM] BloodPressure | Threshold=77.000 | InfoGain=0.0259 | SplitInfo=0.7496 | GainRatio=0.0346
# [NUM] BloodPressure | Threshold=81.000 | InfoGain=0.0211 | SplitInfo=0.6769 | GainRatio=0.0312
# [NUM] BloodPressure | Threshold=85.000 | InfoGain=0.0165 | SplitInfo=0.5917 | GainRatio=0.0279
# [NUM] BloodPressure | Threshold=88.000 | InfoGain=0.0121 | SplitInfo=0.4912 | GainRatio=0.0247
# [NUM] BloodPressure | Threshold=100.000 | InfoGain=0.0039 | SplitInfo=0.2223 | GainRatio=0.0175
# [NUM] SkinThickness | Threshold=7.000 | InfoGain=0.0162 | SplitInfo=0.8113 | GainRatio=0.0199
# [NUM] SkinThickness | Threshold=16.500 | InfoGain=0.0114 | SplitInfo=0.8631 | GainRatio=0.0132
# [NUM] SkinThickness | Threshold=21.000 | InfoGain=0.0076 | SplitInfo=0.9059 | GainRatio=0.0084
# [NUM] SkinThickness | Threshold=23.500 | InfoGain=0.0047 | SplitInfo=0.9403 | GainRatio=0.0050
# [NUM] SkinThickness | Threshold=24.500 | InfoGain=0.0026 | SplitInfo=0.9666 | GainRatio=0.0027
# [NUM] SkinThickness | Threshold=25.500 | InfoGain=0.0927 | SplitInfo=0.9852 | GainRatio=0.0940
# [NUM] SkinThickness | Threshold=27.000 | InfoGain=0.0837 | SplitInfo=0.9963 | GainRatio=0.0840
# [NUM] SkinThickness | Threshold=30.000 | InfoGain=0.0677 | SplitInfo=0.9963 | GainRatio=0.0680
# [NUM] SkinThickness | Threshold=32.500 | InfoGain=0.0606 | SplitInfo=0.9852 | GainRatio=0.0615
# [NUM] SkinThickness | Threshold=33.500 | InfoGain=0.0540 | SplitInfo=0.9666 | GainRatio=0.0558
# [NUM] SkinThickness | Threshold=35.000 | InfoGain=0.0477 | SplitInfo=0.9403 | GainRatio=0.0507
# [NUM] SkinThickness | Threshold=36.500 | InfoGain=0.0362 | SplitInfo=0.8631 | GainRatio=0.0420
# [NUM] SkinThickness | Threshold=38.000 | InfoGain=0.0309 | SplitInfo=0.8113 | GainRatio=0.0381
# [NUM] SkinThickness | Threshold=40.000 | InfoGain=0.0211 | SplitInfo=0.6769 | GainRatio=0.0312
# [NUM] SkinThickness | Threshold=41.500 | InfoGain=0.0121 | SplitInfo=0.4912 | GainRatio=0.0247
# [NUM] SkinThickness | Threshold=43.500 | InfoGain=0.0079 | SplitInfo=0.3712 | GainRatio=0.0214
# [NUM] SkinThickness | Threshold=50.500 | InfoGain=0.0039 | SplitInfo=0.2223 | GainRatio=0.0175
# [NUM] Insulin | Threshold=35.000 | InfoGain=0.0076 | SplitInfo=0.9059 | GainRatio=0.0084
# [NUM] Insulin | Threshold=85.000 | InfoGain=0.1134 | SplitInfo=0.9403 | GainRatio=0.1206
# [NUM] Insulin | Threshold=107.000 | InfoGain=0.1025 | SplitInfo=0.9666 | GainRatio=0.1060
# [NUM] Insulin | Threshold=122.000 | InfoGain=0.0927 | SplitInfo=0.9852 | GainRatio=0.0940
# [NUM] Insulin | Threshold=132.500 | InfoGain=0.0837 | SplitInfo=0.9963 | GainRatio=0.0840
# [NUM] Insulin | Threshold=145.000 | InfoGain=0.0754 | SplitInfo=1.0000 | GainRatio=0.0754
# [NUM] Insulin | Threshold=161.500 | InfoGain=0.0677 | SplitInfo=0.9963 | GainRatio=0.0680
# [NUM] Insulin | Threshold=171.500 | InfoGain=0.0606 | SplitInfo=0.9852 | GainRatio=0.0615
# [NUM] Insulin | Threshold=192.500 | InfoGain=0.0477 | SplitInfo=0.9403 | GainRatio=0.0507
# [NUM] Insulin | Threshold=217.500 | InfoGain=0.0418 | SplitInfo=0.9059 | GainRatio=0.0462
# [NUM] Insulin | Threshold=232.500 | InfoGain=0.0362 | SplitInfo=0.8631 | GainRatio=0.0420
# [NUM] Insulin | Threshold=242.500 | InfoGain=0.0309 | SplitInfo=0.8113 | GainRatio=0.0381
# [NUM] Insulin | Threshold=272.500 | InfoGain=0.0259 | SplitInfo=0.7496 | GainRatio=0.0346
# [NUM] Insulin | Threshold=302.000 | InfoGain=0.0211 | SplitInfo=0.6769 | GainRatio=0.0312
# [NUM] Insulin | Threshold=399.500 | InfoGain=0.0165 | SplitInfo=0.5917 | GainRatio=0.0279
# [NUM] Insulin | Threshold=519.000 | InfoGain=0.0079 | SplitInfo=0.3712 | GainRatio=0.0214
# [NUM] Insulin | Threshold=694.500 | InfoGain=0.0039 | SplitInfo=0.2223 | GainRatio=0.0175
# [NUM] BMI | Threshold=24.550 | InfoGain=0.0039 | SplitInfo=0.2223 | GainRatio=0.0175
# [NUM] BMI | Threshold=26.600 | InfoGain=0.0079 | SplitInfo=0.3712 | GainRatio=0.0214
# [NUM] BMI | Threshold=28.550 | InfoGain=0.0565 | SplitInfo=0.4912 | GainRatio=0.1150
# [NUM] BMI | Threshold=29.900 | InfoGain=0.0412 | SplitInfo=0.5917 | GainRatio=0.0695
# [NUM] BMI | Threshold=30.250 | InfoGain=0.0223 | SplitInfo=0.7496 | GainRatio=0.0298
# [NUM] BMI | Threshold=30.450 | InfoGain=0.0162 | SplitInfo=0.8113 | GainRatio=0.0199
# [NUM] BMI | Threshold=31.050 | InfoGain=0.0076 | SplitInfo=0.9059 | GainRatio=0.0084
# [NUM] BMI | Threshold=32.150 | InfoGain=0.0047 | SplitInfo=0.9403 | GainRatio=0.0050
# [NUM] BMI | Threshold=33.000 | InfoGain=0.0026 | SplitInfo=0.9666 | GainRatio=0.0027
# [NUM] BMI | Threshold=33.500 | InfoGain=0.0011 | SplitInfo=0.9852 | GainRatio=0.0012
# [NUM] BMI | Threshold=33.850 | InfoGain=0.0003 | SplitInfo=0.9963 | GainRatio=0.0003
# [NUM] BMI | Threshold=34.150 | InfoGain=0.0677 | SplitInfo=0.9963 | GainRatio=0.0680
# [NUM] BMI | Threshold=34.400 | InfoGain=0.0606 | SplitInfo=0.9852 | GainRatio=0.0615
# [NUM] BMI | Threshold=35.200 | InfoGain=0.0540 | SplitInfo=0.9666 | GainRatio=0.0558
# [NUM] BMI | Threshold=36.800 | InfoGain=0.0477 | SplitInfo=0.9403 | GainRatio=0.0507
# [NUM] BMI | Threshold=37.850 | InfoGain=0.0418 | SplitInfo=0.9059 | GainRatio=0.0462
# [NUM] BMI | Threshold=38.500 | InfoGain=0.0362 | SplitInfo=0.8631 | GainRatio=0.0420
# [NUM] BMI | Threshold=39.200 | InfoGain=0.0309 | SplitInfo=0.8113 | GainRatio=0.0381
# [NUM] BMI | Threshold=39.600 | InfoGain=0.0259 | SplitInfo=0.7496 | GainRatio=0.0346
# [NUM] BMI | Threshold=40.350 | InfoGain=0.0211 | SplitInfo=0.6769 | GainRatio=0.0312
# [NUM] BMI | Threshold=41.450 | InfoGain=0.0165 | SplitInfo=0.5917 | GainRatio=0.0279
# [NUM] BMI | Threshold=43.700 | InfoGain=0.0121 | SplitInfo=0.4912 | GainRatio=0.0247
# [NUM] BMI | Threshold=46.650 | InfoGain=0.0079 | SplitInfo=0.3712 | GainRatio=0.0214
# [NUM] BMI | Threshold=50.550 | InfoGain=0.0039 | SplitInfo=0.2223 | GainRatio=0.0175
# [NUM] DiabetesPedigreeFunction | Threshold=0.148 | InfoGain=0.0039 | SplitInfo=0.2223 | GainRatio=0.0175
# [NUM] DiabetesPedigreeFunction | Threshold=0.178 | InfoGain=0.0079 | SplitInfo=0.3712 | GainRatio=0.0214
# [NUM] DiabetesPedigreeFunction | Threshold=0.227 | InfoGain=0.0121 | SplitInfo=0.4912 | GainRatio=0.0247
# [NUM] DiabetesPedigreeFunction | Threshold=0.263 | InfoGain=0.0165 | SplitInfo=0.5917 | GainRatio=0.0279
# [NUM] DiabetesPedigreeFunction | Threshold=0.282 | InfoGain=0.0304 | SplitInfo=0.6769 | GainRatio=0.0449
# [NUM] DiabetesPedigreeFunction | Threshold=0.325 | InfoGain=0.1745 | SplitInfo=0.7496 | GainRatio=0.2327
# [NUM] DiabetesPedigreeFunction | Threshold=0.358 | InfoGain=0.1555 | SplitInfo=0.8113 | GainRatio=0.1916
# [NUM] DiabetesPedigreeFunction | Threshold=0.372 | InfoGain=0.1394 | SplitInfo=0.8631 | GainRatio=0.1616
# [NUM] DiabetesPedigreeFunction | Threshold=0.389 | InfoGain=0.1256 | SplitInfo=0.9059 | GainRatio=0.1386
# [NUM] DiabetesPedigreeFunction | Threshold=0.397 | InfoGain=0.1134 | SplitInfo=0.9403 | GainRatio=0.1206
# [NUM] DiabetesPedigreeFunction | Threshold=0.424 | InfoGain=0.1025 | SplitInfo=0.9666 | GainRatio=0.1060
# [NUM] DiabetesPedigreeFunction | Threshold=0.459 | InfoGain=0.0927 | SplitInfo=0.9852 | GainRatio=0.0940
# [NUM] DiabetesPedigreeFunction | Threshold=0.502 | InfoGain=0.0837 | SplitInfo=0.9963 | GainRatio=0.0840
# [NUM] DiabetesPedigreeFunction | Threshold=0.540 | InfoGain=0.0754 | SplitInfo=1.0000 | GainRatio=0.0754
# [NUM] DiabetesPedigreeFunction | Threshold=0.565 | InfoGain=0.0677 | SplitInfo=0.9963 | GainRatio=0.0680
# [NUM] DiabetesPedigreeFunction | Threshold=0.587 | InfoGain=0.0606 | SplitInfo=0.9852 | GainRatio=0.0615
# [NUM] DiabetesPedigreeFunction | Threshold=0.601 | InfoGain=0.0540 | SplitInfo=0.9666 | GainRatio=0.0558
# [NUM] DiabetesPedigreeFunction | Threshold=0.643 | InfoGain=0.0477 | SplitInfo=0.9403 | GainRatio=0.0507
# [NUM] DiabetesPedigreeFunction | Threshold=0.696 | InfoGain=0.0418 | SplitInfo=0.9059 | GainRatio=0.0462
# [NUM] DiabetesPedigreeFunction | Threshold=0.720 | InfoGain=0.0362 | SplitInfo=0.8631 | GainRatio=0.0420
# [NUM] DiabetesPedigreeFunction | Threshold=0.733 | InfoGain=0.0309 | SplitInfo=0.8113 | GainRatio=0.0381
# [NUM] DiabetesPedigreeFunction | Threshold=0.752 | InfoGain=0.0259 | SplitInfo=0.7496 | GainRatio=0.0346
# [NUM] DiabetesPedigreeFunction | Threshold=0.788 | InfoGain=0.0211 | SplitInfo=0.6769 | GainRatio=0.0312
# [NUM] DiabetesPedigreeFunction | Threshold=0.834 | InfoGain=0.0165 | SplitInfo=0.5917 | GainRatio=0.0279
# [NUM] DiabetesPedigreeFunction | Threshold=1.020 | InfoGain=0.0121 | SplitInfo=0.4912 | GainRatio=0.0247
# [NUM] DiabetesPedigreeFunction | Threshold=1.206 | InfoGain=0.0079 | SplitInfo=0.3712 | GainRatio=0.0214
# [NUM] DiabetesPedigreeFunction | Threshold=1.558 | InfoGain=0.0039 | SplitInfo=0.2223 | GainRatio=0.0175
# [NUM] Age | Threshold=24.500 | InfoGain=0.0039 | SplitInfo=0.2223 | GainRatio=0.0175
# [NUM] Age | Threshold=25.500 | InfoGain=0.0121 | SplitInfo=0.4912 | GainRatio=0.0247
# [NUM] Age | Threshold=27.000 | InfoGain=0.0412 | SplitInfo=0.5917 | GainRatio=0.0695
# [NUM] Age | Threshold=28.500 | InfoGain=0.0304 | SplitInfo=0.6769 | GainRatio=0.0449
# [NUM] Age | Threshold=29.500 | InfoGain=0.0223 | SplitInfo=0.7496 | GainRatio=0.0298
# [NUM] Age | Threshold=31.000 | InfoGain=0.0162 | SplitInfo=0.8113 | GainRatio=0.0199
# [NUM] Age | Threshold=32.500 | InfoGain=0.0114 | SplitInfo=0.8631 | GainRatio=0.0132
# [NUM] Age | Threshold=33.500 | InfoGain=0.0047 | SplitInfo=0.9403 | GainRatio=0.0050
# [NUM] Age | Threshold=35.000 | InfoGain=0.0026 | SplitInfo=0.9666 | GainRatio=0.0027
# [NUM] Age | Threshold=37.500 | InfoGain=0.0003 | SplitInfo=0.9963 | GainRatio=0.0003
# [NUM] Age | Threshold=39.500 | InfoGain=0.0000 | SplitInfo=1.0000 | GainRatio=0.0000
# [NUM] Age | Threshold=40.500 | InfoGain=0.0677 | SplitInfo=0.9963 | GainRatio=0.0680
# [NUM] Age | Threshold=41.500 | InfoGain=0.0477 | SplitInfo=0.9403 | GainRatio=0.0507
# [NUM] Age | Threshold=42.500 | InfoGain=0.0418 | SplitInfo=0.9059 | GainRatio=0.0462
# [NUM] Age | Threshold=44.500 | InfoGain=0.0362 | SplitInfo=0.8631 | GainRatio=0.0420
# [NUM] Age | Threshold=46.500 | InfoGain=0.0309 | SplitInfo=0.8113 | GainRatio=0.0381
# [NUM] Age | Threshold=49.000 | InfoGain=0.0259 | SplitInfo=0.7496 | GainRatio=0.0346
# [NUM] Age | Threshold=52.000 | InfoGain=0.0211 | SplitInfo=0.6769 | GainRatio=0.0312
# [NUM] Age | Threshold=53.500 | InfoGain=0.0165 | SplitInfo=0.5917 | GainRatio=0.0279
# [NUM] Age | Threshold=56.000 | InfoGain=0.0121 | SplitInfo=0.4912 | GainRatio=0.0247
# [NUM] Age | Threshold=58.500 | InfoGain=0.0079 | SplitInfo=0.3712 | GainRatio=0.0214
# [NUM] Age | Threshold=59.500 | InfoGain=0.0039 | SplitInfo=0.2223 | GainRatio=0.0175
#    --> Best Feature = DiabetesPedigreeFunction, Best GainRatio = 0.2327, Threshold = 0.32499999999999996
#
#       Entropy(Target) = 0.9183
#       Checking features...
# [NUM] Pregnancies | Threshold=2.500 | InfoGain=0.1092 | SplitInfo=0.6500 | GainRatio=0.1679
# [NUM] Pregnancies | Threshold=5.000 | InfoGain=0.0000 | SplitInfo=1.0000 | GainRatio=0.0000
# [NUM] Pregnancies | Threshold=7.500 | InfoGain=0.1092 | SplitInfo=0.6500 | GainRatio=0.1679
# [NUM] BloodPressure | Threshold=66.000 | InfoGain=0.9183 | SplitInfo=0.9183 | GainRatio=1.0000
# [NUM] BloodPressure | Threshold=69.000 | InfoGain=0.4591 | SplitInfo=1.0000 | GainRatio=0.4591
# [NUM] BloodPressure | Threshold=71.000 | InfoGain=0.2516 | SplitInfo=0.9183 | GainRatio=0.2740
# [NUM] BloodPressure | Threshold=75.000 | InfoGain=0.1092 | SplitInfo=0.6500 | GainRatio=0.1679
# [NUM] SkinThickness | Threshold=12.500 | InfoGain=0.0441 | SplitInfo=0.9183 | GainRatio=0.0480
# [NUM] SkinThickness | Threshold=29.000 | InfoGain=0.4591 | SplitInfo=1.0000 | GainRatio=0.4591
# [NUM] SkinThickness | Threshold=36.000 | InfoGain=0.2516 | SplitInfo=0.9183 | GainRatio=0.2740
# [NUM] SkinThickness | Threshold=42.000 | InfoGain=0.1092 | SplitInfo=0.6500 | GainRatio=0.1679
# [NUM] Insulin | Threshold=35.000 | InfoGain=0.0441 | SplitInfo=0.9183 | GainRatio=0.0480
# [NUM] Insulin | Threshold=102.500 | InfoGain=0.4591 | SplitInfo=1.0000 | GainRatio=0.4591
# [NUM] Insulin | Threshold=219.500 | InfoGain=0.2516 | SplitInfo=0.9183 | GainRatio=0.2740
# [NUM] Insulin | Threshold=423.500 | InfoGain=0.1092 | SplitInfo=0.6500 | GainRatio=0.1679
# [NUM] BMI | Threshold=28.950 | InfoGain=0.3167 | SplitInfo=0.6500 | GainRatio=0.4872
# [NUM] BMI | Threshold=31.900 | InfoGain=0.0441 | SplitInfo=0.9183 | GainRatio=0.0480
# [NUM] BMI | Threshold=33.650 | InfoGain=0.0000 | SplitInfo=1.0000 | GainRatio=0.0000
# [NUM] BMI | Threshold=35.850 | InfoGain=0.2516 | SplitInfo=0.9183 | GainRatio=0.2740
# [NUM] BMI | Threshold=42.800 | InfoGain=0.1092 | SplitInfo=0.6500 | GainRatio=0.1679
# [NUM] Age | Threshold=25.000 | InfoGain=0.1092 | SplitInfo=0.6500 | GainRatio=0.1679
# [NUM] Age | Threshold=33.000 | InfoGain=0.0441 | SplitInfo=0.9183 | GainRatio=0.0480
# [NUM] Age | Threshold=40.500 | InfoGain=0.4591 | SplitInfo=1.0000 | GainRatio=0.4591
# [NUM] Age | Threshold=42.000 | InfoGain=0.2516 | SplitInfo=0.9183 | GainRatio=0.2740
# [NUM] Age | Threshold=48.000 | InfoGain=0.1092 | SplitInfo=0.6500 | GainRatio=0.1679
#       --> Best Feature = BloodPressure, Best GainRatio = 1.0000, Threshold = 66.0
#
# Final Decision Tree:
# {'Glucose': {'< 154.5': {'BMI': {'< 47.8': {'Pregnancies': {'< 14.0': {'DiabetesPedigreeFunction': {'< 2.0345': {'Age': {'< 22.5': 0,
#                                                                                                                          '>= 22.5': {'Insulin': {'< 232.5': {'BloodPressure': {'< 93.0': {'SkinThickness': {'< 48.5': 0,
#                                                                                                                                                                                                             '>= 48.5': 0}},
#                                                                                                                                                                                '>= 93.0': {'SkinThickness': {'< 16.5': 1,
#                                                                                                                                                                                                              '>= 16.5': 1}}}},
#                                                                                                                                                  '>= 232.5': 0}}}},
#                                                                                                     '>= 2.0345': 1}},
#                                                             '>= 14.0': 1}},
#                                  '>= 47.8': 1}},
#              '>= 154.5': {'DiabetesPedigreeFunction': {'< 0.32499999999999996': {'BloodPressure': {'< 66.0': 0,
#                                                                                                    '>= 66.0': 1}},
#                                                        '>= 0.32499999999999996': 1}}}}
